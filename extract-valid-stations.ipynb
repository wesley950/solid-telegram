# %% [markdown]
# # Extração
#
# Usaremos este caderno para identificar quais estações podemos usar. Se você quiser executar este caderno, pode fazer o download do arquivo XML com as estações visitando [este endereço](https://dadosabertos.ana.gov.br/documents/ae318ebacb4b41cda37fbdd82125078b/explore), colocando 2 no campo **tpEst**; 4 no campo **codBacia**; e 0 no campo **telemetrica**. Isso listará todas as estações cadastradas do tipo **pluviométrica** (cód. 2), na bacia do São Francisco (cód. 4), e que não são telemétricas.
#
# Esse arquivo não foi incluído no repositório por ter tamanho elevado.

# %%
# Get stations from HidroInventario.xml

from xml.dom.minidom import parse

with open("data/HidroInventario.xml", "r") as f:
    doc = parse(f)

stations = doc.getElementsByTagName("Estacoes")[0].getElementsByTagName("Table")

# %%
# Filter out stations that have started working less than 20 years ago or stopped along the way

from datetime import datetime, timedelta

limit_date = datetime.now()
threshold_date = limit_date - timedelta(days=365 * 20)
valid_stations = []

for station in stations:
    try:
        # check start date
        started_working = (
            station.getElementsByTagName("PeriodoPluviometroInicio")[0]
            .childNodes[0]
            .nodeValue
        )
        started_working = datetime.fromisoformat(started_working)

        # check if started 20 or more years ago
        if started_working >= threshold_date:
            continue

        # check if stopped working
        stopped_working = station.getElementsByTagName("PeriodoPluviometroFim")[
            0
        ].childNodes

        if len(stopped_working):
            continue
        else:
            print(
                f'Station {station.getElementsByTagName("Codigo")[0].childNodes[0].nodeValue} started working on {started_working} and never stopped'
            )

        # extract info
        try:
            sub_basin = (
                station.getElementsByTagName("SubBaciaCodigo")[0]
                .childNodes[0]
                .nodeValue
            )
            station_id = (
                station.getElementsByTagName("Codigo")[0].childNodes[0].nodeValue
            )
            latitude = (
                station.getElementsByTagName("Latitude")[0].childNodes[0].nodeValue
            )
            longitude = (
                station.getElementsByTagName("Longitude")[0].childNodes[0].nodeValue
            )
            nome = station.getElementsByTagName("Nome")[0].childNodes[0].nodeValue
            state = station.getElementsByTagName("nmEstado")[0].childNodes[0].nodeValue
            municipality = (
                station.getElementsByTagName("nmMunicipio")[0].childNodes[0].nodeValue
            )

            valid_stations.append(
                {
                    "sub_basin": sub_basin,
                    "station": station_id,
                    "latitude": latitude,
                    "longitude": longitude,
                    "name": nome.title(),
                    "state": state.title(),
                    "municipality": municipality.title(),
                }
            )
        except:
            print(f"Failed to extract info from station")

    except IndexError:
        continue

print(f"Found {len(valid_stations)} valid stations")
# Out:
# Station 737027 started working on 1911-08-01 00:00:00 and never stopped
# Station 737036 started working on 1914-09-01 00:00:00 and never stopped
# Station 737040 started working on 1979-01-01 00:00:00 and never stopped
# Station 737042 started working on 1979-02-01 00:00:00 and never stopped
# Station 737043 started working on 1979-08-01 00:00:00 and never stopped
# Station 737044 started working on 1979-08-01 00:00:00 and never stopped
# Station 737045 started working on 1979-07-01 00:00:00 and never stopped
# Station 737046 started working on 1979-01-01 00:00:00 and never stopped
# Station 737048 started working on 1979-01-01 00:00:00 and never stopped
# Station 737049 started working on 1979-01-01 00:00:00 and never stopped
# Station 737050 started working on 1979-01-01 00:00:00 and never stopped
# Station 737051 started working on 1979-01-01 00:00:00 and never stopped
# Station 738032 started working on 1911-09-01 00:00:00 and never stopped
# Station 738035 started working on 1953-06-01 00:00:00 and never stopped
# Station 738043 started working on 1979-10-01 00:00:00 and never stopped
# Station 738044 started working on 1979-07-01 00:00:00 and never stopped
# Station 738045 started working on 1979-01-01 00:00:00 and never stopped
# Station 738046 started working on 1979-02-01 00:00:00 and never stopped
# Station 738048 started working on 1985-11-01 00:00:00 and never stopped
# Station 739028 started working on 1934-12-01 00:00:00 and never stopped
# Station 739029 started working on 1934-12-01 00:00:00 and never stopped
# Station 739040 started working on 1979-03-01 00:00:00 and never stopped
# Station 739041 started working on 1982-04-01 00:00:00 and never stopped
# Station 739042 started working on 1979-01-01 00:00:00 and never stopped
# Station 739043 started working on 1981-03-01 00:00:00 and never stopped
# Station 739044 started working on 1979-11-01 00:00:00 and never stopped
# Station 740015 started working on 1959-02-01 00:00:00 and never stopped
# Station 740016 started working on 1934-12-01 00:00:00 and never stopped
# Station 740017 started working on 1934-12-01 00:00:00 and never stopped
# Station 740025 started working on 1961-10-01 00:00:00 and never stopped
# Station 740029 started working on 1975-09-01 00:00:00 and never stopped
# Station 740030 started working on 1979-01-01 00:00:00 and never stopped
# Station 740031 started working on 1979-01-01 00:00:00 and never stopped
# Station 740032 started working on 1979-01-01 00:00:00 and never stopped
# Station 740033 started working on 1981-11-01 00:00:00 and never stopped
# Station 836029 started working on 1920-06-01 00:00:00 and never stopped
# Station 836053 started working on 1934-03-01 00:00:00 and never stopped
# Station 836064 started working on 1979-10-01 00:00:00 and never stopped
# Station 836081 started working on 1979-09-01 00:00:00 and never stopped
# Station 837007 started working on 1960-01-01 00:00:00 and never stopped
# Station 837009 started working on 1920-06-01 00:00:00 and never stopped
# Station 837011 started working on 1933-11-01 00:00:00 and never stopped
# Station 837025 started working on 1934-11-01 00:00:00 and never stopped
# Station 837028 started working on 1934-11-01 00:00:00 and never stopped
# Station 837030 started working on 1958-12-01 00:00:00 and never stopped
# Station 837038 started working on 1972-04-01 00:00:00 and never stopped
# Station 837039 started working on 1933-11-01 00:00:00 and never stopped
# Station 837044 started working on 1979-02-01 00:00:00 and never stopped
# Station 837045 started working on 1979-07-01 00:00:00 and never stopped
# Station 837046 started working on 1979-08-01 00:00:00 and never stopped
# Station 837047 started working on 1979-08-01 00:00:00 and never stopped
# Station 837048 started working on 1979-10-01 00:00:00 and never stopped
# Station 837049 started working on 1979-07-01 00:00:00 and never stopped
# Station 837050 started working on 1980-12-01 00:00:00 and never stopped
# Station 837051 started working on 1979-07-01 00:00:00 and never stopped
# Station 837053 started working on 2004-11-01 00:00:00 and never stopped
# Station 838000 started working on 1934-11-01 00:00:00 and never stopped
# Station 838001 started working on 1962-11-01 00:00:00 and never stopped
# Station 838002 started working on 1962-11-01 00:00:00 and never stopped
# Station 838004 started working on 1946-09-01 00:00:00 and never stopped
# Station 838005 started working on 1934-11-01 00:00:00 and never stopped
# Station 838009 started working on 1920-06-01 00:00:00 and never stopped
# Station 838013 started working on 1934-11-01 00:00:00 and never stopped
# Station 838016 started working on 1937-09-01 00:00:00 and never stopped
# Station 838021 started working on 1972-05-01 00:00:00 and never stopped
# Station 838023 started working on 1937-01-01 00:00:00 and never stopped
# Station 838027 started working on 1934-12-01 00:00:00 and never stopped
# Station 838031 started working on 1972-04-01 00:00:00 and never stopped
# Station 838035 started working on 1952-09-01 00:00:00 and never stopped
# Station 838039 started working on 1979-07-01 00:00:00 and never stopped
# Station 838040 started working on 1979-10-01 00:00:00 and never stopped
# Station 838041 started working on 1979-02-01 00:00:00 and never stopped
# Station 838042 started working on 1979-02-01 00:00:00 and never stopped
# Station 838043 started working on 1979-01-01 00:00:00 and never stopped
# Station 838044 started working on 1979-01-01 00:00:00 and never stopped
# Station 839002 started working on 1911-04-01 00:00:00 and never stopped
# Station 839004 started working on 1927-12-01 00:00:00 and never stopped
# Station 839009 started working on 1962-10-01 00:00:00 and never stopped
# Station 839012 started working on 1911-04-01 00:00:00 and never stopped
# Station 839013 started working on 1968-11-01 00:00:00 and never stopped
# Station 839014 started working on 1962-10-01 00:00:00 and never stopped
# Station 839015 started working on 1934-12-01 00:00:00 and never stopped
# Station 839018 started working on 1911-04-01 00:00:00 and never stopped
# Station 839027 started working on 1934-01-01 00:00:00 and never stopped
# Station 839031 started working on 1972-07-01 00:00:00 and never stopped
# Station 839034 started working on 1972-07-01 00:00:00 and never stopped
# Station 839035 started working on 1999-01-01 00:00:00 and never stopped
# Station 839039 started working on 1979-01-01 00:00:00 and never stopped
# Station 839040 started working on 1979-01-01 00:00:00 and never stopped
# Station 839041 started working on 1979-10-01 00:00:00 and never stopped
# Station 839042 started working on 1979-01-01 00:00:00 and never stopped
# Station 839043 started working on 1979-02-01 00:00:00 and never stopped
# Station 839044 started working on 1982-01-01 00:00:00 and never stopped
# Station 839046 started working on 2002-11-01 00:00:00 and never stopped
# Station 840001 started working on 1934-05-01 00:00:00 and never stopped
# Station 840010 started working on 1962-11-01 00:00:00 and never stopped
# Station 840012 started working on 1935-01-01 00:00:00 and never stopped
# Station 840015 started working on 1962-10-01 00:00:00 and never stopped
# Station 840017 started working on 1934-05-01 00:00:00 and never stopped
# Station 840019 started working on 1934-12-01 00:00:00 and never stopped
# Station 840021 started working on 1934-12-01 00:00:00 and never stopped
# Station 840026 started working on 1979-02-01 00:00:00 and never stopped
# Station 840027 started working on 1979-07-01 00:00:00 and never stopped
# Station 936020 started working on 1912-12-01 00:00:00 and never stopped
# Station 936028 started working on 1913-06-01 00:00:00 and never stopped
# Station 936050 started working on 1912-07-01 00:00:00 and never stopped
# Station 936065 started working on 1929-01-01 00:00:00 and never stopped
# Station 936066 started working on 1963-01-01 00:00:00 and never stopped
# Station 936076 started working on 1999-01-01 00:00:00 and never stopped
# Station 937000 started working on 1920-06-01 00:00:00 and never stopped
# Station 937004 started working on 1920-06-01 00:00:00 and never stopped
# Station 937007 started working on 1912-06-01 00:00:00 and never stopped
# Station 937008 started working on 1928-05-01 00:00:00 and never stopped
# Station 937012 started working on 1937-05-01 00:00:00 and never stopped
# Station 937013 started working on 1936-04-01 00:00:00 and never stopped
# Station 937014 started working on 1914-01-01 00:00:00 and never stopped
# Station 937015 started working on 1929-01-01 00:00:00 and never stopped
# Station 937018 started working on 1912-12-01 00:00:00 and never stopped
# Station 937019 started working on 1912-06-01 00:00:00 and never stopped
# Station 937022 started working on 1912-06-01 00:00:00 and never stopped
# Station 937023 started working on 1935-01-01 00:00:00 and never stopped
# Station 937026 started working on 1913-07-01 00:00:00 and never stopped
# Station 937028 started working on 1912-06-01 00:00:00 and never stopped
# Station 937029 started working on 1937-04-01 00:00:00 and never stopped
# Station 937030 started working on 1936-04-01 00:00:00 and never stopped
# Station 937031 started working on 1962-09-01 00:00:00 and never stopped
# Station 937039 started working on 1979-01-01 00:00:00 and never stopped
# Station 937040 started working on 2004-10-01 00:00:00 and never stopped
# Station 938002 started working on 1920-06-01 00:00:00 and never stopped
# Station 938007 started working on 1918-03-01 00:00:00 and never stopped
# Station 938013 started working on 1959-11-01 00:00:00 and never stopped
# Station 938014 started working on 1959-10-01 00:00:00 and never stopped
# Station 938015 started working on 1936-04-01 00:00:00 and never stopped
# Station 938020 started working on 1913-06-01 00:00:00 and never stopped
# Station 938023 started working on 1938-11-01 00:00:00 and never stopped
# Station 938025 started working on 1979-09-01 00:00:00 and never stopped
# Station 938026 started working on 1979-10-01 00:00:00 and never stopped
# Station 938030 started working on 2004-11-01 00:00:00 and never stopped
# Station 939000 started working on 1933-12-01 00:00:00 and never stopped
# Station 939008 started working on 1911-06-01 00:00:00 and never stopped
# Station 939009 started working on 1959-11-01 00:00:00 and never stopped
# Station 939011 started working on 1944-01-01 00:00:00 and never stopped
# Station 939017 started working on 1972-08-01 00:00:00 and never stopped
# Station 939020 started working on 2004-10-01 00:00:00 and never stopped
# Station 939022 started working on 2004-11-01 00:00:00 and never stopped
# Station 940005 started working on 1934-05-01 00:00:00 and never stopped
# Station 940006 started working on 1911-03-01 00:00:00 and never stopped
# Station 940009 started working on 1934-01-01 00:00:00 and never stopped
# Station 940016 started working on 1911-01-01 00:00:00 and never stopped
# Station 940018 started working on 1947-01-01 00:00:00 and never stopped
# Station 940020 started working on 1933-11-01 00:00:00 and never stopped
# Station 940023 started working on 1959-11-01 00:00:00 and never stopped
# Station 940025 started working on 1972-08-01 00:00:00 and never stopped
# Station 940038 started working on 1979-07-01 00:00:00 and never stopped
# Station 941004 started working on 1942-06-01 00:00:00 and never stopped
# Station 941011 started working on 1911-07-01 00:00:00 and never stopped
# Station 941012 started working on 1937-12-01 00:00:00 and never stopped
# Station 941017 started working on 2004-11-01 00:00:00 and never stopped
# Station 941018 started working on 2004-11-01 00:00:00 and never stopped
# Station 942012 started working on 1942-06-01 00:00:00 and never stopped
# Station 942016 started working on 1911-11-01 00:00:00 and never stopped
# Station 942020 started working on 1911-04-01 00:00:00 and never stopped
# Station 942030 started working on 1978-12-01 00:00:00 and never stopped
# Station 1036003 started working on 1963-01-01 00:00:00 and never stopped
# Station 1036004 started working on 1912-02-01 00:00:00 and never stopped
# Station 1036005 started working on 1935-01-01 00:00:00 and never stopped
# Station 1036007 started working on 1928-09-01 00:00:00 and never stopped
# Station 1036009 started working on 1912-02-01 00:00:00 and never stopped
# Station 1036021 started working on 1920-06-01 00:00:00 and never stopped
# Station 1036025 started working on 1923-01-01 00:00:00 and never stopped
# Station 1036050 started working on 1943-10-01 00:00:00 and never stopped
# Station 1036055 started working on 1927-01-01 00:00:00 and never stopped
# Station 1037003 started working on 1912-03-01 00:00:00 and never stopped
# Station 1040018 started working on 1937-11-01 00:00:00 and never stopped
# Station 1040028 started working on 2002-11-01 00:00:00 and never stopped
# Station 1040036 started working on 2004-10-01 00:00:00 and never stopped
# Station 1041002 started working on 1918-01-01 00:00:00 and never stopped
# Station 1041007 started working on 1919-07-01 00:00:00 and never stopped
# Station 1041016 started working on 2004-11-01 00:00:00 and never stopped
# Station 1042001 started working on 1937-11-01 00:00:00 and never stopped
# Station 1042007 started working on 1911-06-01 00:00:00 and never stopped
# Station 1042012 started working on 1972-04-01 00:00:00 and never stopped
# Station 1042018 started working on 1984-12-01 00:00:00 and never stopped
# Station 1043004 started working on 1940-09-01 00:00:00 and never stopped
# Station 1044007 started working on 1936-08-01 00:00:00 and never stopped
# Station 1046002 started working on 2002-08-01 00:00:00 and never stopped
# Station 1141007 started working on 1943-09-01 00:00:00 and never stopped
# Station 1141014 started working on 1973-01-01 00:00:00 and never stopped
# Station 1141023 started working on 2000-04-01 00:00:00 and never stopped
# Station 1141026 started working on 1999-08-01 00:00:00 and never stopped
# Station 1142004 started working on 1937-11-01 00:00:00 and never stopped
# Station 1142013 started working on 1937-11-01 00:00:00 and never stopped
# Station 1142014 started working on 1937-12-01 00:00:00 and never stopped
# Station 1142017 started working on 1963-12-01 00:00:00 and never stopped
# Station 1142020 started working on 1972-04-01 00:00:00 and never stopped
# Station 1142023 started working on 2000-04-01 00:00:00 and never stopped
# Station 1143001 started working on 1936-08-01 00:00:00 and never stopped
# Station 1143005 started working on 1925-03-01 00:00:00 and never stopped
# Station 1143006 started working on 1911-08-01 00:00:00 and never stopped
# Station 1143009 started working on 1936-08-01 00:00:00 and never stopped
# Station 1144002 started working on 1919-07-01 00:00:00 and never stopped
# Station 1144027 started working on 1984-01-01 00:00:00 and never stopped
# Station 1145001 started working on 1941-08-01 00:00:00 and never stopped
# Station 1145003 started working on 1939-08-01 00:00:00 and never stopped
# Station 1145004 started working on 1962-08-01 00:00:00 and never stopped
# Station 1145012 started working on 1941-09-01 00:00:00 and never stopped
# Station 1145013 started working on 1962-03-01 00:00:00 and never stopped
# Station 1145015 started working on 1973-01-01 00:00:00 and never stopped
# Station 1145020 started working on 2000-09-01 00:00:00 and never stopped
# Station 1145025 started working on 2004-05-01 00:00:00 and never stopped
# Station 1145029 started working on 2004-04-01 00:00:00 and never stopped
# Station 1242006 started working on 1937-11-01 00:00:00 and never stopped
# Station 1242008 started working on 1936-08-01 00:00:00 and never stopped
# Station 1242012 started working on 1938-01-01 00:00:00 and never stopped
# Station 1242016 started working on 1972-05-01 00:00:00 and never stopped
# Station 1242020 started working on 2000-04-01 00:00:00 and never stopped
# Station 1243000 started working on 1958-11-01 00:00:00 and never stopped
# Station 1243006 started working on 1911-06-01 00:00:00 and never stopped
# Station 1243007 started working on 1937-11-01 00:00:00 and never stopped
# Station 1243010 started working on 1936-09-01 00:00:00 and never stopped
# Station 1243011 started working on 1952-08-01 00:00:00 and never stopped
# Station 1243013 started working on 1936-10-01 00:00:00 and never stopped
# Station 1244004 started working on 1936-09-01 00:00:00 and never stopped
# Station 1244008 started working on 1936-09-01 00:00:00 and never stopped
# Station 1244011 started working on 1936-05-01 00:00:00 and never stopped
# Station 1244018 started working on 1936-09-01 00:00:00 and never stopped
# Station 1244021 started working on 2002-12-01 00:00:00 and never stopped
# Station 1245001 started working on 1939-07-01 00:00:00 and never stopped
# Station 1245009 started working on 1952-08-01 00:00:00 and never stopped
# Station 1245016 started working on 2000-08-01 00:00:00 and never stopped
# Station 1245017 started working on 2002-08-01 00:00:00 and never stopped
# Station 1245019 started working on 2001-06-01 00:00:00 and never stopped
# Station 1245020 started working on 2001-06-01 00:00:00 and never stopped
# Station 1245022 started working on 2001-06-01 00:00:00 and never stopped
# Station 1245023 started working on 2001-06-01 00:00:00 and never stopped
# Station 1245026 started working on 2001-06-01 00:00:00 and never stopped
# Station 1245027 started working on 2001-08-01 00:00:00 and never stopped
# Station 1245028 started working on 2004-05-01 00:00:00 and never stopped
# Station 1245029 started working on 2004-05-01 00:00:00 and never stopped
# Station 1245030 started working on 2004-04-01 00:00:00 and never stopped
# Station 1246005 started working on 2001-06-01 00:00:00 and never stopped
# Station 1246006 started working on 2001-06-01 00:00:00 and never stopped
# Station 1341009 started working on 1960-01-01 00:00:00 and never stopped
# Station 1342001 started working on 1933-05-01 00:00:00 and never stopped
# Station 1342003 started working on 1942-06-01 00:00:00 and never stopped
# Station 1342009 started working on 1934-01-01 00:00:00 and never stopped
# Station 1342011 started working on 1917-05-01 00:00:00 and never stopped
# Station 1342013 started working on 1912-01-01 00:00:00 and never stopped
# Station 1342015 started working on 1934-01-01 00:00:00 and never stopped
# Station 1343001 started working on 1939-08-01 00:00:00 and never stopped
# Station 1343009 started working on 1939-07-01 00:00:00 and never stopped
# Station 1343017 started working on 1939-07-01 00:00:00 and never stopped
# Station 1343022 started working on 1967-11-01 00:00:00 and never stopped
# Station 1343025 started working on 2002-09-01 00:00:00 and never stopped
# Station 1344001 started working on 1936-10-01 00:00:00 and never stopped
# Station 1344004 started working on 1936-10-01 00:00:00 and never stopped
# Station 1344010 started working on 1919-06-01 00:00:00 and never stopped
# Station 1344014 started working on 1952-11-01 00:00:00 and never stopped
# Station 1344017 started working on 1939-06-01 00:00:00 and never stopped
# Station 1344024 started working on 1975-08-01 00:00:00 and never stopped
# Station 1344025 started working on 2002-11-01 00:00:00 and never stopped
# Station 1345003 started working on 2002-11-01 00:00:00 and never stopped
# Station 1345007 started working on 2004-05-01 00:00:00 and never stopped
# Station 1346010 started working on 2004-05-01 00:00:00 and never stopped
# Station 1346011 started working on 2004-05-01 00:00:00 and never stopped
# Station 1442002 started working on 1942-05-01 00:00:00 and never stopped
# Station 1442004 started working on 1935-03-01 00:00:00 and never stopped
# Station 1442006 started working on 1933-05-01 00:00:00 and never stopped
# Station 1442009 started working on 1933-05-01 00:00:00 and never stopped
# Station 1442010 started working on 1939-06-01 00:00:00 and never stopped
# Station 1442019 started working on 1954-11-01 00:00:00 and never stopped
# Station 1442025 started working on 1974-03-01 00:00:00 and never stopped
# Station 1442031 started working on 1984-05-01 00:00:00 and never stopped
# Station 1442032 started working on 2000-08-01 00:00:00 and never stopped
# Station 1442033 started working on 2001-01-01 00:00:00 and never stopped
# Station 1442034 started working on 2001-01-01 00:00:00 and never stopped
# Station 1442035 started working on 2001-01-01 00:00:00 and never stopped
# Station 1442036 started working on 2001-01-01 00:00:00 and never stopped
# Station 1442037 started working on 2001-01-01 00:00:00 and never stopped
# Station 1442038 started working on 2001-01-01 00:00:00 and never stopped
# Station 1442039 started working on 2002-02-01 00:00:00 and never stopped
# Station 1442040 started working on 2002-12-01 00:00:00 and never stopped
# Station 1443001 started working on 1938-09-01 00:00:00 and never stopped
# Station 1443002 started working on 1937-01-01 00:00:00 and never stopped
# Station 1443015 started working on 1911-06-01 00:00:00 and never stopped
# Station 1443018 started working on 1911-06-01 00:00:00 and never stopped
# Station 1443022 started working on 1927-09-01 00:00:00 and never stopped
# Station 1443027 started working on 2001-01-01 00:00:00 and never stopped
# Station 1443028 started working on 2001-01-01 00:00:00 and never stopped
# Station 1443029 started working on 2002-12-01 00:00:00 and never stopped
# Station 1444000 started working on 1946-06-01 00:00:00 and never stopped
# Station 1444001 started working on 1950-09-01 00:00:00 and never stopped
# Station 1444003 started working on 1967-01-01 00:00:00 and never stopped
# Station 1444004 started working on 1964-04-01 00:00:00 and never stopped
# Station 1444005 started working on 1969-05-01 00:00:00 and never stopped
# Station 1444015 started working on 1943-06-01 00:00:00 and never stopped
# Station 1444018 started working on 2001-04-01 00:00:00 and never stopped
# Station 1444019 started working on 2002-01-01 00:00:00 and never stopped
# Station 1445001 started working on 2004-05-01 00:00:00 and never stopped
# Station 1445002 started working on 2004-05-01 00:00:00 and never stopped
# Station 1446003 started working on 1976-04-01 00:00:00 and never stopped
# Station 1542011 started working on 1974-03-01 00:00:00 and never stopped
# Station 1542016 started working on 1983-01-01 00:00:00 and never stopped
# Station 1542017 started working on 2002-01-01 00:00:00 and never stopped
# Station 1542018 started working on 2002-02-01 00:00:00 and never stopped
# Station 1543010 started working on 1951-02-01 00:00:00 and never stopped
# Station 1543017 started working on 1975-03-01 00:00:00 and never stopped
# Station 1543018 started working on 2000-08-01 00:00:00 and never stopped
# Station 1543021 started working on 2002-01-01 00:00:00 and never stopped
# Station 1543022 started working on 2002-01-01 00:00:00 and never stopped
# Station 1543023 started working on 2001-01-01 00:00:00 and never stopped
# Station 1543024 started working on 2002-12-01 00:00:00 and never stopped
# Station 1543026 started working on 2002-01-01 00:00:00 and never stopped
# Station 1544006 started working on 1912-06-01 00:00:00 and never stopped
# Station 1544007 started working on 1963-01-01 00:00:00 and never stopped
# Station 1544013 started working on 1960-01-01 00:00:00 and never stopped
# Station 1544014 started working on 1960-01-01 00:00:00 and never stopped
# Station 1544017 started working on 1972-08-01 00:00:00 and never stopped
# Station 1544018 started working on 1974-10-01 00:00:00 and never stopped
# Station 1544020 started working on 1912-06-01 00:00:00 and never stopped
# Station 1544024 started working on 1964-10-01 00:00:00 and never stopped
# Station 1544029 started working on 1975-11-01 00:00:00 and never stopped
# Station 1544032 started working on 1993-07-01 00:00:00 and never stopped
# Station 1544036 started working on 2000-08-01 00:00:00 and never stopped
# Station 1544037 started working on 2000-08-01 00:00:00 and never stopped
# Station 1544038 started working on 2001-04-01 00:00:00 and never stopped
# Station 1544039 started working on 2001-01-01 00:00:00 and never stopped
# Station 1544040 started working on 2001-01-01 00:00:00 and never stopped
# Station 1544041 started working on 2002-10-01 00:00:00 and never stopped
# Station 1544042 started working on 2001-01-01 00:00:00 and never stopped
# Station 1544047 started working on 2002-02-01 00:00:00 and never stopped
# Station 1544048 started working on 2002-01-01 00:00:00 and never stopped
# Station 1545002 started working on 1981-04-01 00:00:00 and never stopped
# Station 1545003 started working on 1985-05-01 00:00:00 and never stopped
# Station 1545005 started working on 2000-08-01 00:00:00 and never stopped
# Station 1545006 started working on 2000-08-01 00:00:00 and never stopped
# Station 1545007 started working on 2001-04-01 00:00:00 and never stopped
# Station 1546001 started working on 1972-05-01 00:00:00 and never stopped
# Station 1546008 started working on 1976-04-01 00:00:00 and never stopped
# Station 1546010 started working on 1993-03-01 00:00:00 and never stopped
# Station 1546012 started working on 2002-01-01 00:00:00 and never stopped
# Station 1547021 started working on 1978-10-01 00:00:00 and never stopped
# Station 1547022 started working on 1978-10-01 00:00:00 and never stopped
# Station 1643002 started working on 1963-01-01 00:00:00 and never stopped
# Station 1643007 started working on 1962-01-01 00:00:00 and never stopped
# Station 1643010 started working on 1950-09-01 00:00:00 and never stopped
# Station 1643024 started working on 1986-11-01 00:00:00 and never stopped
# Station 1643028 started working on 2000-08-01 00:00:00 and never stopped
# Station 1643030 started working on 2002-09-01 00:00:00 and never stopped
# Station 1643031 started working on 2002-02-01 00:00:00 and never stopped
# Station 1643032 started working on 2002-02-01 00:00:00 and never stopped
# Station 1643033 started working on 2001-01-01 00:00:00 and never stopped
# Station 1643034 started working on 2002-01-01 00:00:00 and never stopped
# Station 1643035 started working on 2001-01-01 00:00:00 and never stopped
# Station 1643036 started working on 2002-12-01 00:00:00 and never stopped
# Station 1643037 started working on 2002-12-01 00:00:00 and never stopped
# Station 1643039 started working on 2002-01-01 00:00:00 and never stopped
# Station 1644002 started working on 1961-12-01 00:00:00 and never stopped
# Station 1644007 started working on 1960-01-01 00:00:00 and never stopped
# Station 1644032 started working on 2000-08-01 00:00:00 and never stopped
# Station 1644033 started working on 2000-08-01 00:00:00 and never stopped
# Station 1644035 started working on 2001-01-01 00:00:00 and never stopped
# Station 1644036 started working on 2002-01-01 00:00:00 and never stopped
# Station 1644037 started working on 2001-04-01 00:00:00 and never stopped
# Station 1644038 started working on 2001-01-01 00:00:00 and never stopped
# Station 1644039 started working on 2001-04-01 00:00:00 and never stopped
# Station 1644040 started working on 2002-01-01 00:00:00 and never stopped
# Station 1644041 started working on 2002-01-01 00:00:00 and never stopped
# Station 1644042 started working on 2002-12-01 00:00:00 and never stopped
# Station 1644043 started working on 2002-01-01 00:00:00 and never stopped
# Station 1644044 started working on 2002-01-01 00:00:00 and never stopped
# Station 1645002 started working on 1962-09-01 00:00:00 and never stopped
# Station 1645005 started working on 1956-01-01 00:00:00 and never stopped
# Station 1645007 started working on 1945-07-01 00:00:00 and never stopped
# Station 1645013 started working on 1974-11-01 00:00:00 and never stopped
# Station 1645015 started working on 1976-04-01 00:00:00 and never stopped
# Station 1645018 started working on 1955-10-01 00:00:00 and never stopped
# Station 1645019 started working on 1984-07-01 00:00:00 and never stopped
# Station 1645020 started working on 2000-08-01 00:00:00 and never stopped
# Station 1645021 started working on 2002-01-01 00:00:00 and never stopped
# Station 1646001 started working on 1964-08-01 00:00:00 and never stopped
# Station 1646003 started working on 1956-11-01 00:00:00 and never stopped
# Station 1647008 started working on 1972-05-01 00:00:00 and never stopped
# Station 1743000 started working on 1962-03-01 00:00:00 and never stopped
# Station 1743013 started working on 1943-01-01 00:00:00 and never stopped
# Station 1743022 started working on 2002-01-01 00:00:00 and never stopped
# Station 1744030 started working on 1983-01-01 00:00:00 and never stopped
# Station 1744036 started working on 2001-11-01 00:00:00 and never stopped
# Station 1744037 started working on 2001-11-01 00:00:00 and never stopped
# Station 1744038 started working on 2002-01-01 00:00:00 and never stopped
# Station 1744039 started working on 2002-01-01 00:00:00 and never stopped
# Station 1744040 started working on 2002-01-01 00:00:00 and never stopped
# Station 1744044 started working on 2004-11-01 00:00:00 and never stopped
# Station 1744045 started working on 2004-11-01 00:00:00 and never stopped
# Station 1745016 started working on 2004-11-01 00:00:00 and never stopped
# Station 1746000 started working on 1941-05-01 00:00:00 and never stopped
# Station 1746001 started working on 1962-10-01 00:00:00 and never stopped
# Station 1746002 started working on 1968-01-01 00:00:00 and never stopped
# Station 1746013 started working on 1918-05-01 00:00:00 and never stopped
# Station 1746017 started working on 1983-01-01 00:00:00 and never stopped
# Station 1746018 started working on 1983-02-01 00:00:00 and never stopped
# Station 1746019 started working on 1983-02-01 00:00:00 and never stopped
# Station 1746021 started working on 2002-01-01 00:00:00 and never stopped
# Station 1746022 started working on 2002-01-01 00:00:00 and never stopped
# Station 1746023 started working on 2002-01-01 00:00:00 and never stopped
# Station 1747009 started working on 2002-01-01 00:00:00 and never stopped
# Station 1843000 started working on 1941-08-01 00:00:00 and never stopped
# Station 1843020 started working on 2004-11-01 00:00:00 and never stopped
# Station 1844017 started working on 1984-01-01 00:00:00 and never stopped
# Station 1844018 started working on 1983-01-01 00:00:00 and never stopped
# Station 1844022 started working on 2001-06-01 00:00:00 and never stopped
# Station 1844023 started working on 2001-01-01 00:00:00 and never stopped
# Station 1845002 started working on 1968-08-01 00:00:00 and never stopped
# Station 1845006 started working on 1965-02-01 00:00:00 and never stopped
# Station 1845014 started working on 1958-07-01 00:00:00 and never stopped
# Station 1845031 started working on 2002-01-01 00:00:00 and never stopped
# Station 1845032 started working on 2004-11-01 00:00:00 and never stopped
# Station 1846003 started working on 1968-08-01 00:00:00 and never stopped
# Station 1846015 started working on 1958-07-01 00:00:00 and never stopped
# Station 1846016 started working on 1958-07-01 00:00:00 and never stopped
# Station 1846028 started working on 2002-01-01 00:00:00 and never stopped
# Station 1846029 started working on 2002-01-01 00:00:00 and never stopped
# Station 1846030 started working on 2002-01-01 00:00:00 and never stopped
# Station 1846031 started working on 2004-11-01 00:00:00 and never stopped
# Station 1941024 started working on 2002-01-01 00:00:00 and never stopped
# Station 1943004 started working on 1941-08-01 00:00:00 and never stopped
# Station 1943006 started working on 1941-06-01 00:00:00 and never stopped
# Station 1943009 started working on 1941-04-01 00:00:00 and never stopped
# Station 1943023 started working on 1942-01-01 00:00:00 and never stopped
# Station 1943042 started working on 1974-10-01 00:00:00 and never stopped
# Station 1943047 started working on 1943-01-01 00:00:00 and never stopped
# Station 1943055 started working on 1910-03-01 00:00:00 and never stopped
# Station 1943063 started working on 1918-01-01 00:00:00 and never stopped
# Station 1943066 started working on 1977-10-01 00:00:00 and never stopped
# Station 1943073 started working on 1983-05-01 00:00:00 and never stopped
# Station 1943078 started working on 2000-07-01 00:00:00 and never stopped
# Station 1943079 started working on 2002-10-01 00:00:00 and never stopped
# Station 1943082 started working on 2002-01-01 00:00:00 and never stopped
# Station 1943083 started working on 2002-01-01 00:00:00 and never stopped
# Station 1944007 started working on 1941-03-01 00:00:00 and never stopped
# Station 1944010 started working on 1941-05-01 00:00:00 and never stopped
# Station 1944011 started working on 1941-07-01 00:00:00 and never stopped
# Station 1944024 started working on 1961-02-01 00:00:00 and never stopped
# Station 1944026 started working on 1970-05-01 00:00:00 and never stopped
# Station 1944027 started working on 1970-06-01 00:00:00 and never stopped
# Station 1944031 started working on 1973-09-01 00:00:00 and never stopped
# Station 1944051 started working on 1960-04-01 00:00:00 and never stopped
# Station 1944052 started working on 1926-05-01 00:00:00 and never stopped
# Station 1944055 started working on 1976-02-01 00:00:00 and never stopped
# Station 1944059 started working on 1984-05-01 00:00:00 and never stopped
# Station 1944063 started working on 1995-03-01 00:00:00 and never stopped
# Station 1944068 started working on 1999-11-01 00:00:00 and never stopped
# Station 1944069 started working on 2001-09-01 00:00:00 and never stopped
# Station 1944070 started working on 2001-09-01 00:00:00 and never stopped
# Station 1944071 started working on 2001-10-01 00:00:00 and never stopped
# Station 1944072 started working on 2001-11-01 00:00:00 and never stopped
# Station 1944074 started working on 2002-01-01 00:00:00 and never stopped
# Station 1944075 started working on 2002-01-01 00:00:00 and never stopped
# Station 1944076 started working on 2002-01-01 00:00:00 and never stopped
# Station 1944077 started working on 2001-09-01 00:00:00 and never stopped
# Station 1945002 started working on 1941-06-01 00:00:00 and never stopped
# Station 1945004 started working on 1941-09-01 00:00:00 and never stopped
# Station 1945008 started working on 1974-10-01 00:00:00 and never stopped
# Station 1945019 started working on 1958-07-01 00:00:00 and never stopped
# Station 1945022 started working on 1972-11-01 00:00:00 and never stopped
# Station 1945035 started working on 1974-10-01 00:00:00 and never stopped
# Station 1945039 started working on 1983-01-01 00:00:00 and never stopped
# Station 1945040 started working on 1981-01-01 00:00:00 and never stopped
# Station 1945045 started working on 2001-11-01 00:00:00 and never stopped
# Station 1945046 started working on 2002-01-01 00:00:00 and never stopped
# Station 1945047 started working on 2002-02-01 00:00:00 and never stopped
# Station 1945048 started working on 2002-02-01 00:00:00 and never stopped
# Station 1945049 started working on 2002-02-01 00:00:00 and never stopped
# Station 1945050 started working on 2001-11-01 00:00:00 and never stopped
# Station 1945051 started working on 2001-11-01 00:00:00 and never stopped
# Station 1945052 started working on 2002-02-01 00:00:00 and never stopped
# Station 1945056 started working on 2002-01-01 00:00:00 and never stopped
# Station 1945057 started working on 2002-01-01 00:00:00 and never stopped
# Station 1946000 started working on 1941-08-01 00:00:00 and never stopped
# Station 1946020 started working on 2000-08-01 00:00:00 and never stopped
# Station 1946023 started working on 2002-02-01 00:00:00 and never stopped
# Station 1946026 started working on 2002-02-01 00:00:00 and never stopped
# Station 2043004 started working on 1912-01-01 00:00:00 and never stopped
# Station 2043005 started working on 1940-12-01 00:00:00 and never stopped
# Station 2043013 started working on 1941-05-01 00:00:00 and never stopped
# Station 2043042 started working on 1976-09-01 00:00:00 and never stopped
# Station 2043043 started working on 1976-09-01 00:00:00 and never stopped
# Station 2043047 started working on 2002-08-01 00:00:00 and never stopped
# Station 2043056 started working on 1984-01-01 00:00:00 and never stopped
# Station 2043060 started working on 1984-01-01 00:00:00 and never stopped
# Station 2043071 started working on 2002-01-01 00:00:00 and never stopped
# Station 2043072 started working on 2002-01-01 00:00:00 and never stopped
# Station 2043073 started working on 2001-08-01 00:00:00 and never stopped
# Station 2044002 started working on 1941-03-01 00:00:00 and never stopped
# Station 2044006 started working on 1941-05-01 00:00:00 and never stopped
# Station 2044008 started working on 1941-07-01 00:00:00 and never stopped
# Station 2044012 started working on 1945-01-01 00:00:00 and never stopped
# Station 2044016 started working on 1970-05-01 00:00:00 and never stopped
# Station 2044019 started working on 1970-05-01 00:00:00 and never stopped
# Station 2044020 started working on 1970-05-01 00:00:00 and never stopped
# Station 2044024 started working on 1972-12-01 00:00:00 and never stopped
# Station 2044026 started working on 1974-04-01 00:00:00 and never stopped
# Station 2044039 started working on 1959-04-01 00:00:00 and never stopped
# Station 2044041 started working on 1976-11-01 00:00:00 and never stopped
# Station 2044043 started working on 1976-12-01 00:00:00 and never stopped
# Station 2044053 started working on 1985-12-01 00:00:00 and never stopped
# Station 2044054 started working on 1987-05-01 00:00:00 and never stopped
# Station 2044066 started working on 2002-01-01 00:00:00 and never stopped
# Station 2044067 started working on 2002-01-01 00:00:00 and never stopped
# Station 2044068 started working on 2002-01-01 00:00:00 and never stopped
# Station 2044069 started working on 2002-01-01 00:00:00 and never stopped
# Station 2044070 started working on 2002-01-01 00:00:00 and never stopped
# Station 2044072 started working on 2002-01-01 00:00:00 and never stopped
# Station 2044074 started working on 1965-02-01 00:00:00 and never stopped
# Station 2045001 started working on 1941-01-01 00:00:00 and never stopped
# Station 2045002 started working on 1941-01-01 00:00:00 and never stopped
# Station 2045005 started working on 1941-05-01 00:00:00 and never stopped
# Station 2045010 started working on 1974-10-01 00:00:00 and never stopped
# Station 2045011 started working on 1974-10-01 00:00:00 and never stopped
# Station 2045013 started working on 1974-12-01 00:00:00 and never stopped
# Station 2045023 started working on 1926-08-01 00:00:00 and never stopped
# Station 2045032 started working on 2002-02-01 00:00:00 and never stopped
# Station 2045033 started working on 2002-01-01 00:00:00 and never stopped
# Station 2046025 started working on 1984-02-01 00:00:00 and never stopped
# Station 2046040 started working on 2002-01-01 00:00:00 and never stopped
# Found 525 valid stations

# %% [markdown]
# Aqui salvamos as estações numa outra planilha, que podemos usar para fazer o download das séries históricas visitando o [site da HidroWeb](https://www.snirh.gov.br/hidroweb/serieshistoricas) com as séries históricas.

# %%
# Save valid stations to csv

import pandas as pd

with open("stations.csv", "w") as f:
    df = pd.DataFrame(valid_stations)
    df.to_csv(f, index=False)
